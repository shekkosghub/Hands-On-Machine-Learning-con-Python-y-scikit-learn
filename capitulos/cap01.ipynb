# %%
# Instalar una librería específica
# !pip install scikit-learn --quiet

# Verificar la versión instalada
import sklearn
print(sklearn.__version__)

# %%
# Montar Google Drive — pedirá permisos la primera vez
from google.colab import drive
from pathlib import Path

try:
    drive.mount('/content/drive')
    print('Drive montado correctamente')
except Exception as e:
    print(f'Error al montar Drive: {e}')

# %%
# Crear carpeta del curso en Drive (solo la primera vez)
ruta_curso = Path('/content/drive/MyDrive/ML_con_sklearn')
ruta_curso.mkdir(parents=True, exist_ok=True)
print(f'Carpeta lista: {ruta_curso}')

# Verificar los primeros archivos en tu Drive
archivos = list(Path('/content/drive/MyDrive').iterdir())[:5]
for f in archivos:
    print(f.name)

# %%
# Verificar GPU — PyTorch viene preinstalado en Colab
import torch
if torch.cuda.is_available():
    nombre_gpu = torch.cuda.get_device_name(0)
    print(f'GPU activa: {nombre_gpu}')
else:
    print('Sin GPU. Actívala en Entorno de ejecución → Cambiar tipo')
